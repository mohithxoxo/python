# %%
# !pip install yfinance

# %%
import yfinance as yf
tickerSymbol = 'HCLTECH.NS'
tickerData = yf.Ticker(tickerSymbol)
HCLTECH = tickerData.history(period='1d', start='2014-03-1', end='2020-03-31')
HCLTECH
# Out:
#               Open    High     Low   Close    Volume  Dividends  Stock Splits
# Date
# 2014-03-03  317.65  317.65  300.68  303.27   8926652        0.0           0.0
# 2014-03-04  304.75  307.37  297.30  298.58   6936724        0.0           0.0
# 2014-03-05  299.69  301.20  292.93  294.76   8011076        0.0           0.0
# 2014-03-06  296.16  302.23  296.08  300.69   7490368        0.0           0.0
# 2014-03-07  300.72  303.34  293.51  299.89   8818956        0.0           0.0
# ...            ...     ...     ...     ...       ...        ...           ...
# 2020-03-24  413.00  458.85  411.85  442.05   9915953        0.0           0.0
# 2020-03-25  432.00  468.00  417.75  457.60  11976272        0.0           0.0
# 2020-03-26  461.10  466.75  441.10  447.70   9504717        0.0           0.0
# 2020-03-27  450.25  457.45  420.50  430.65   9150873        0.0           0.0
# 2020-03-30  410.00  438.65  410.00  419.00   6325701        0.0           0.0
#
# [1492 rows x 7 columns]

# %%
import yfinance as yf
tickerSymbol = 'TCS.NS'
tickerData = yf.Ticker(tickerSymbol)
TCS = tickerData.history(period='1d', start='2014-03-1', end='2020-03-31')
TCS
# Out:
#                Open     High      Low  ...   Volume  Dividends  Stock Splits
# Date                                   ...
# 2014-03-03   949.12   960.48   930.82  ...  1606078        0.0           0.0
# 2014-03-04   932.99   941.68   929.14  ...  2030332        0.0           0.0
# 2014-03-05   942.04   955.15   936.90  ...  2302006        0.0           0.0
# 2014-03-06   941.20   944.19   932.55  ...  1314562        0.0           0.0
# 2014-03-07   938.13   940.03   899.40  ...  4698472        0.0           0.0
# ...             ...      ...      ...  ...      ...        ...           ...
# 2020-03-24  1653.05  1770.00  1632.85  ...  6350865        0.0           0.0
# 2020-03-25  1700.00  1810.00  1680.00  ...  2765520        0.0           0.0
# 2020-03-26  1831.60  1832.05  1722.55  ...  4556067        0.0           0.0
# 2020-03-27  1820.00  1850.00  1750.40  ...  4331250        0.0           0.0
# 2020-03-30  1766.00  1905.00  1763.55  ...  8513547        0.0           0.0
#
# ...

# %%
import yfinance as yf
tickerSymbol = 'INFY.NS'
tickerData = yf.Ticker(tickerSymbol)
INFY = tickerData.history(period='1d', start='2014-03-1', end='2020-03-31')
INFY
# Out:
#               Open    High     Low   Close    Volume  Dividends  Stock Splits
# Date
# 2014-03-03  298.41  300.35  295.83  296.32   7204176        0.0           0.0
# 2014-03-04  294.12  298.36  293.48  296.42   6937912        0.0           0.0
# 2014-03-05  298.63  299.92  297.23  298.15   4943504        0.0           0.0
# 2014-03-06  299.42  300.35  297.81  298.95   6226312        0.0           0.0
# 2014-03-07  298.56  299.11  289.30  291.80  15072744        0.0           0.0
# ...            ...     ...     ...     ...       ...        ...           ...
# 2020-03-24  522.00  601.15  522.00  589.80  20027097        0.0           0.0
# 2020-03-25  597.00  635.00  565.70  606.20  18339548        0.0           0.0
# 2020-03-26  615.00  650.85  612.10  643.00  14843813        0.0           0.0
# 2020-03-27  665.05  674.90  642.25  652.70  13495283        0.0           0.0
# 2020-03-30  625.10  663.50  621.10  626.70  14624804        0.0           0.0
#
# [1492 rows x 7 columns]

# %%
import yfinance as yf
tickerSymbol = 'TECHM.NS'
tickerData = yf.Ticker(tickerSymbol)
TECHM = tickerData.history(period='1d', start='2014-03-1', end='2020-03-31')
TECHM
# Out:
#               Open    High     Low   Close   Volume  Dividends  Stock Splits
# Date
# 
.0
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
HCLTECH['Close'].plot()
plt.show()

# %%
data = [TCS['Close'],INFY['Close'],HCLTECH['Close'],WIPRO['Close'],TECHM['Close']]
data = pd.DataFrame(data).transpose()
data = pd.DataFrame(data.values)
data = data.rename(columns={0:"TCS",1 : "INFY" , 2 : "HCL" , 3 : "WIPRO", 4 : "TECHM" })
data
# Out:
#           TCS    INFY     HCL   WIPRO   TECHM
# 0      935.85  296.32  303.27  187.34  413.53
# 1      936.10  296.42  298.58  188.08  412.13
# 2      940.80  298.15  294.76  188.81  412.97
# 3      936.15  298.95  300.69  187.00  417.16
# 4      931.03  291.80  299.89  180.77  398.25
# ...       ...     ...     ...     ...     ...
# 1487  1703.15  589.80  442.05  176.35  503.50
# 1488  1750.30  606.20  457.60  174.65  526.70
# 1489  1790.95  643.00  447.70  182.60  515.20
# 1490  1824.50  652.70  430.65  183.50  504.10
# 1491  1778.50  626.70  419.00  184.15  526.80
#
# [1492 rows x 5 columns]

# %%
data.plot(figsize=(10, 7))
plt.legend()
plt.title("Adjusted Close Price (31/03/2020) of TOP 5 IT companies ", fontsize=16)
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %%
tickers_list = ['TCS.NS','INFY.NS','HCLTECH.NS','WIPRO.NS','TECHM.NS']

import pandas as pd
data = pd.DataFrame(columns=tickers_list)

import yfinance as yf
for ticker in tickers_list:
  data[ticker] = yf.download(ticker, period='5y',)['Adj Close']
data = data.pct_change().dropna().mean(axis=1)
data.head()
# Out:
# ...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Date
# 2015-04-28    0.001005
# 2015-04-29    0.009505
# 2015-04-30   -0.005008
# 2015-05-04    0.013458
# 2015-05-05   -0.001028
# dtype: float64

# %%
import pyfolio as pf
pf.create_full_tear_sheet(data)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2015-04-28</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-04-27</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>58</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>7.3%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>41.2%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>20.1%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.45</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.23</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.79</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-32.3%</td>
#     </tr>
#     <tr>
# ...

# %%
print("TECHM vs TCS " , np.corrcoef(TECHM['Close'],TCS['Close']), "\n"
,"TECHM vs INFY " ,np.corrcoef(TECHM['Close'],INFY['Close']), "\n"
,"TECHM vs HCLTECH" , np.corrcoef(TECHM['Close'],HCLTECH['Close']), "\n"
,"TECHM vs WIPRO", np.corrcoef(TECHM['Close'],WIPRO['Close']))
# Out:
# TECHM vs TCS  [[1.         0.86790543]
#  [0.86790543 1.        ]]
#  TECHM vs INFY  [[1.         0.80197499]
#  [0.80197499 1.        ]]
#  TECHM vs HCLTECH [[1.         0.79356837]
#  [0.79356837 1.        ]]
#  TECHM vs WIPRO [[1.         0.77623091]
#  [0.77623091 1.        ]]

# %%
data.corr()
# Out:
#             TCS      INFY       HCL     WIPRO     TECHM
# TCS    1.000000  0.943050  0.914199  0.830480  0.867905
# INFY   0.943050  1.000000  0.905734  0.815041  0.801975
# HCL    0.914199  0.905734  1.000000  0.823917  0.793568
# WIPRO  0.830480  0.815041  0.823917  1.000000  0.776231
# TECHM  0.867905  0.801975  0.793568  0.776231  1.000000

# %%
df = data

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)), df.columns)
plt.yticks(range(len(df.columns)), df.columns)
plt.colorbar()
plt.show()

# %%
data
# Out:
#           TCS    INFY     HCL   WIPRO   TECHM
# 0      935.85  296.32  303.27  187.34  413.53
# 1      936.10  296.42  298.58  188.08  412.13
# 2      940.80  298.15  294.76  188.81  412.97
# 3      936.15  298.95  300.69  187.00  417.16
# 4      931.03  291.80  299.89  180.77  398.25
# ...       ...     ...     ...     ...     ...
# 1487  1703.15  589.80  442.05  176.35  503.50
# 1488  1750.30  606.20  457.60  174.65  526.70
# 1489  1790.95  643.00  447.70  182.60  515.20
# 1490  1824.50  652.70  430.65  183.50  504.10
# 1491  1778.50  626.70  419.00  184.15  526.80
#
# [1492 rows x 5 columns]

# %%
TCS['Volume'].plot(figsize=(16,8),label = "TCS",title='Volume')
INFY['Volume'].plot(label = "INFY")
HCLTECH['Volume'].plot(label = "HCLTECH")
WIPRO['Volume'].plot(label = "WIPRO")
TECHM['Volume'].plot(label = "TECHM")
plt.legend();

# %%
TCS['Total Traded'] = TCS['Open'] * TCS['Volume']
INFY['Total Traded'] = INFY['Open'] * INFY['Volume']
HCLTECH['Total Traded'] = HCLTECH['Open'] * HCLTECH['Volume']
WIPRO['Total Traded'] = WIPRO['Open'] * WIPRO['Volume']
TECHM['Total Traded'] = TECHM['Open'] * TECHM['Volume']

# %%
TCS['Total Traded'].plot(figsize=(16,8),label = "TCS",title='Total Money Traded')
INFY['Total Traded'].plot(label = "INFY")
HCLTECH['Total Traded'].plot(label = "HCLTECH")
WIPRO['Total Traded'].plot(label = "WIPRO")
TECHM['Total Traded'].plot(label = "TECHM")
plt.legend()
plt.ylabel('Total Money Traded')
# Out:
# Text(0, 0.5, 'Total Money Traded')

# %%
TCS['returns'] = TCS['Close'].pct_change(1)
INFY['returns'] = INFY['Close'].pct_change(1)
HCLTECH['returns'] = HCLTECH['Close'].pct_change(1)
WIPRO['returns'] = WIPRO['Close'].pct_change(1)
TECHM['returns'] = TECHM['Close'].pct_change(1)

# %%
TCS['returns'].hist(bins=100)

# %%
INFY['returns'].hist(bins=100)

# %%
HCLTECH['returns'].hist(bins=100)

# %%
WIPRO['returns'].hist(bins=100)

# %%
TECHM['returns'].hist(bins=100)

# %%
TCS['returns'].hist(bins=50,label='TCS',figsize = (10,8), alpha= 0.5)
INFY['returns'].hist(bins=50,label='INFY', alpha= 0.5)
HCLTECH['returns'].hist(bins=50,label='HCLTECH', alpha= 0.5)
WIPRO['returns'].hist(bins=50,label='WIPRO', alpha= 0.5)
TECHM['returns'].hist(bins=50,label='TECHM', alpha= 0.5)
plt.xlabel('Returns')
plt.legend();

# %%
TCS['daily_cumulative_return'] = ( 1 + TCS['returns'] ).cumprod()
INFY['daily_cumulative_return'] = ( 1 + INFY['returns'] ).cumprod()
HCLTECH['daily_cumulative_return'] = ( 1 + HCLTECH['returns'] ).cumprod()
WIPRO['daily_cumulative_return'] = ( 1 + WIPRO['returns'] ).cumprod()
TECHM['daily_cumulative_return'] = ( 1 + TECHM['returns'] ).cumprod()

# %%
TCS['daily_cumulative_return'].plot(label='TCS',figsize = (16,8),title = 'Cumilative Return')
INFY['daily_cumulative_return'].plot(label='INFY')
HCLTECH['daily_cumulative_return'].plot(label='HCLTECH')
WIPRO['daily_cumulative_return'].plot(label='WIPRO')
TECHM['daily_cumulative_return'].plot(label='TECHM')
plt.legend();
